# %% [markdown]
# ### **apply()** - Calculate Project Salary Next Year

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df["salary_year_avg"]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 785736   NaN
# 785737   NaN
# 785738   NaN
# 785739   NaN
# 785740   NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df[pd.notna(df["salary_year_avg"])]
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
df_salary = df[pd.notna(df["salary_year_avg"])].copy()

# %%
df_salary["salary_year_avg"]
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %% [markdown]
# #### Calculate salary_year_avg in next year --> 3% inflation

# %%
help(df.apply)
# Out:
# Help on method apply in module pandas.core.frame:
#
# apply(func: 'AggFuncType', axis: 'Axis' = 0, raw: 'bool' = False, result_type: "Literal['expand', 'reduce', 'broadcast'] | None" = None, args=(), by_row: "Literal[False, 'compat']" = 'compat', engine: "Literal['python', 'numba']" = 'python', engine_kwargs: 'dict[str, bool] | None' = None, **kwargs) method of pandas.core.frame.DataFrame instance
#     Apply a function along an axis of the DataFrame.
#
#     Objects passed to the function are Series objects whose index is
#     either the DataFrame's index (``axis=0``) or the DataFrame's columns
#     (``axis=1``). By default (``result_type=None``), the final return type
#     is inferred from the return type of the applied function. Otherwise,
#     it depends on the `result_type` argument.
#
#     Parameters
#     ----------
#     func : function
#         Function to apply to each column or row.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
def projected_salary(salary):
    return salary * 1.03

# %%
df_salary["salary_year_avg"].apply(projected_salary)
# Out:
# 28        112785.00
# 77        144200.00
# 92        123600.00
# 100       235068.66
# 109        91670.00
#             ...
# 785624    143392.48
# 785641    154500.00
# 785648    228531.25
# 785682    162225.00
# 785692    162225.00
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
df_salary["salary_year_inflated"] = df_salary["salary_year_avg"].apply(projected_salary)

# %%
df_salary[["salary_year_avg", "salary_year_inflated"]]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %% [markdown]
# Another method without using function in apply()  --> Lambda

# %%
df_salary["salary_year_inflated"] = df_salary["salary_year_avg"].apply(lambda salary: salary * 1.03)

# %%
df_salary[["salary_year_avg", "salary_year_inflated"]]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df_salary["salary_year_inflated"] = df_salary["salary_year_avg"] * 1.03
df_salary[["salary_year_avg", "salary_year_inflated"]]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %% [markdown]
# #### Convert job_skills from string --> list

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df["job_skills"]
# Out:
# 0                                                      None
# 1         ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2         ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3         ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4         ['bash', 'python', 'oracle', 'aws', 'ansible',...
#                                 ...
# 785736    ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                       ['sas', 'sas', 'sql', 'excel']
# 785738                              ['powerpoint', 'excel']
# 785739    ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                      ['aws', 'flow']
# Name: job_skills, Length: 785741, dtype: object

# %%
df["job_skills"][0]  # none Value

# %%
type(df["job_skills"][0])
# Out:
# NoneType

# %%
df["job_skills"][1]
# Out:
# "['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']"

# %%
type(df["job_skills"][1])
# Out:
# str

# %%
import ast

# %%
ast.literal_eval(df["job_skills"][1])
# Out:
# ['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']

# %%
type(ast.literal_eval(df["job_skills"][1]))
# Out:
# list

# %%
def clean_list(skill_list):
    return ast.literal_eval(skill_list)

# %%
df["job_skills"] = df["job_skills"].apply(clean_list)  # cannot convert None Values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df["job_skills"] = df["job_skills"].apply(clean_list)  # cannot convert None Values
#
# File d:\Anaconda\envs\course\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
df[pd.isna(df["job_skills"])]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 21            Data Scientist
# 26             Data Engineer
# 29            Data Scientist
# 36              Data Analyst
# ...                      ...
# 785713        Cloud Engineer
# 785715          Data Analyst
# 785718      Business Analyst
# 785724         Data Engineer
# 785729         Data Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 21      Stage - data scientist – génération ia de donn...
# 26                                          Data Engineer
# 29                                         Data Scientist
# 36                                           Data Analyst
# ...                                                   ...
# 785713  Data Center Chief Engineer, AWS Infrastructure...
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785718                      Senior Performance QA Analyst
# ...

# %%
def clean_list(skill_list):
    if pd.notna(skill_list):
        return ast.literal_eval(skill_list)

# %%
df_copy = df.copy()  # for lambda method

# %%
df["job_skills"] = df["job_skills"].apply(clean_list)  # now it works becouse we don't use function on None Values --> if statment

# %%
df["job_skills"][0]

# %%
type(df["job_skills"][0])
# Out:
# NoneType

# %%
df["job_skills"][1]
# Out:
# ['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']

# %%
type(df["job_skills"][1])
# Out:
# list

# %% [markdown]
# #### using lambda instead function

# %%
df_copy["job_skills"] = df_copy["job_skills"].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)

# %%
df_copy["job_skills"][0]

# %%
type(df_copy["job_skills"][0])
# Out:
# NoneType

# %%
df_copy["job_skills"][1]
# Out:
# ['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']

# %%
type(df_copy["job_skills"][1])
# Out:
# list

# %% [markdown]
# ### Calculate projected salary next year
# - #### Senior roles assume 5%
# - #### Other roles assume 3%

# %%
help(df.apply)
# Out:
# Help on method apply in module pandas.core.frame:
#
# apply(func: 'AggFuncType', axis: 'Axis' = 0, raw: 'bool' = False, result_type: "Literal['expand', 'reduce', 'broadcast'] | None" = None, args=(), by_row: "Literal[False, 'compat']" = 'compat', engine: "Literal['python', 'numba']" = 'python', engine_kwargs: 'dict[str, bool] | None' = None, **kwargs) method of pandas.core.frame.DataFrame instance
#     Apply a function along an axis of the DataFrame.
#
#     Objects passed to the function are Series objects whose index is
#     either the DataFrame's index (``axis=0``) or the DataFrame's columns
#     (``axis=1``). By default (``result_type=None``), the final return type
#     is inferred from the return type of the applied function. Otherwise,
#     it depends on the `result_type` argument.
#
#     Parameters
#     ----------
#     func : function
#         Function to apply to each column or row.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
df_salary
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
def projected_salary(row):
    if "Senior" in row["job_title_short"]:
        return 1.05 * row["salary_year_avg"]
    else:
        return 1.03 * row["salary_year_avg"]

# %%
df_salary["salary_year_inflated"] = df_salary.apply(projected_salary, axis=1)

# %%
df_salary[["job_title_short", "salary_year_avg", "salary_year_inflated"]]
# Out:
#        job_title_short  salary_year_avg  salary_year_inflated
# 28      Data Scientist         109500.0             112785.00
# 77       Data Engineer         140000.0             144200.00
# 92       Data Engineer         120000.0             123600.00
# 100     Data Scientist         228222.0             235068.66
# 109       Data Analyst          89000.0              91670.00
# ...                ...              ...                   ...
# 785624   Data Engineer         139216.0             143392.48
# 785641   Data Engineer         150000.0             154500.00
# 785648  Data Scientist         221875.0             228531.25
# 785682  Data Scientist         157500.0             162225.00
# 785692  Data Scientist         157500.0             162225.00
#
# [22003 rows x 3 columns]

# %%
df_salary[df_salary["job_title_short"].str.contains("Senior")]
# Out:
#               job_title_short  \
# 495      Senior Data Engineer
# 573      Senior Data Engineer
# 657      Senior Data Engineer
# 726      Senior Data Engineer
# 733      Senior Data Engineer
# ...                       ...
# 784947   Senior Data Engineer
# 785106   Senior Data Engineer
# 785132  Senior Data Scientist
# 785330  Senior Data Scientist
# 785340  Senior Data Scientist
#
#                                                 job_title  \
# 495                       Senior Software Engineer (Data)
# 573                           Senior Python Data Engineer
# 657     Senior Data Engineer | Series D Video Analytic...
# 726                         Senior Data Engineer (Hybrid)
# 733                                  Senior Data Engineer
# ...                                                   ...
# 784947                               Senior Data Engineer
# 785106                               Senior Data Engineer
# 785132            Senior Database Designer / Data Modeler
# ...
