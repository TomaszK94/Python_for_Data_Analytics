# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# from previous section 08
df["job_posted_month"] = df["job_posted_date"].dt.strftime("%b")
months = df["job_posted_month"].unique()
dict_months = {month: df[df["job_posted_month"] == month] for month in months}
df_q1 = pd.concat([dict_months["Jan"], dict_months["Feb"], dict_months["Mar"]], ignore_index=True)
df_q1
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df_q1.head(5).to_clipboard(sep=",")  # coppied data to clipboard --> on ctrl + v

# %%
df_q1.to_csv("quarter1.csv", index=False)

# %%
pd.read_csv("quarter1.csv")
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %%
pd.read_csv("quarter1.csv", index_col=0)  # only needed if we saved as csv without index=False
# Out:
#                                                            job_title  \
# job_title_short
# Data Analyst                                            Data Analyst
# Data Scientist                                        Data Scientist
# Data Engineer                                          Data Engineer
# Data Engineer                                          Data Engineer
# Data Scientist                                        Data Scientist
# ...                                                              ...
# Software Engineer                                    DevOps Engineer
# Data Analyst                                        CRM Data Analyst
# Business Analyst                      Commercial Analyst - Start Now
# Data Engineer      Principal Associate, Data Engineer (Remote-Eli...
# Software Engineer                                 AWS System Analyst
#
#                                             job_location  \
# job_title_short
# ...

# %%
# need to instal module
# conda instal openpyxl

# %%
df_q1.to_excel("quarter1.xlsx")

# %% [markdown]
# ### to_sql()
# Need to setup database of sql...

# %%
# from sqlalchemy import create_engine
# engine = create_engine("sqlite:///jobs.db")

# df.to_sql("job_table", con=engine, if_exists="append", index=False)

# %% [markdown]
# ### to_parquet()
# Large DataSets
#
# Export and Load to Python faster then another likes csv

# %%
df.to_parquet("jobs_data.parquet")

# %% [markdown]
# ### to_pickle()
# Large DataSets
#
# Export and Load to Python faster then another likes csv

# %%
df.to_pickle("jobs_data.pkl")
